# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
data = pd.read_csv('data_clean.csv')
data.head()
print(data.shape)
# Out:
# (1974, 19)

# %%
data1 = data.drop(['ID','Contact'], axis=1)
print(data1.shape)
data1.head()
# Out:
# (1974, 17)
#                                          Name            Assemble       Type  \
# 0      Hyundai Creta Tiêu chuẩn 1.5 AT - 2022           Nhập khẩu  Crossover
# 1   Hyundai SantaFe Cao cấp 2.5L HTRAC - 2022  Lắp ráp trong nước        SUV
# 2                Mazda CX8 Premium AWD - 2019  Lắp ráp trong nước        SUV
# 3               Hyundai Tucson 2.0 ATH - 2015           Nhập khẩu  Crossover
# 4                     Toyota Venza 2.7 - 2009           Nhập khẩu  Crossover
#
#       Km CarColor InteriorColor  CarDoor  CarSeat     Gearbox  Price  \
# 0      0    Trắng           Đen        5        5  Số tự động    620
# 1      0    Trắng           Nâu        5        7  Số tự động   1240
# 2  20000       Đỏ           Nâu        5        7  Số tự động   1048
# 3  36000    Trắng           Kem        5        5  Số tự động    725
# 4  60000      Bạc           Ghi        5        5  Số tự động    518
#
#    Location  Year Status EngineCar  Capacity Trademark  ProductionYear
# ...

# %%
y=data1.Price
X=data1.drop('Price', axis=1)
y
# Out:
# 0        620
# 1       1240
# 2       1048
# 3        725
# 4        518
#         ...
# 1969     575
# 1970     845
# 1971     835
# 1972    2050
# 1973     605
# Name: Price, Length: 1974, dtype: int64

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# %%
labels = ["Price"]

# %%
quali_feature = ['Assemble', 'Status', 'Gearbox']
plt.figure(figsize = (30,20))
sns.boxplot(x=data1.Assemble, y=data1.Price, palette=("cubehelix"))
# Out:
# <AxesSubplot:xlabel='Assemble', ylabel='Price'>

# %%
quali_feature = ['Assemble', 'Status', 'Gearbox']
plt.figure(figsize = (30,20))
sns.boxplot(x=data1.Status, y=data1.Price, palette=("cubehelix"))
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Price'>

# %%
quali_feature = ['Assemble', 'Status', 'Gearbox']
plt.figure(figsize = (30,20))
sns.boxplot(x=data1.Gearbox, y=data1.Price, palette=("cubehelix"))
# Out:
# <AxesSubplot:xlabel='Gearbox', ylabel='Price'>

# %%
quali_feature = ['Assemble', 'Status', 'Gearbox']
plt.figure(figsize = (30,20))
sns.boxplot(x=data1.Location, y=data1.Price, palette=("cubehelix"))
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Price'>
